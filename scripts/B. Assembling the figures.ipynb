# %%
from IPython.display import Image, display

# %% [markdown]
# # Figure 1

# %%
# %%capture
# %%bash
pdflatex <<TeXScript
\documentclass{standalone}
\usepackage{tikz,graphicx}
\usepackage[T1]{fontenc}

\begin{document}
\begin{tikzpicture}
    \node[anchor=north west] {\includegraphics{../figures/draft/fig-incper_BA1.pdf}};
    \node[anchor=south east] at (.1in,-.25in) {\Large{\bf A}};
    \node[anchor=south east] at (.1in, -4.5in) {\Large{\bf B}};
\end{tikzpicture}
\end{document}
TeXScript
mv texput.pdf ../figures/Figure1.pdf
rm texput.*

# %%
# !convert -flatten -density 150 -trim ../figures/Figure1.pdf -quality 100 ../figures/pngs/Figure1.png
# !convert -flatten -density 300 -trim ../figures/Figure1.pdf -compress LZW -quality 100 ../figures/Figure1.tif
display(Image("../figures/pngs/Figure1.png", width=600))

# %% [markdown]
# # Figure 2

# %%
# !convert -flatten -density 150 -trim ../figures/Figure2-PubMed.pdf -quality 100 ../figures/pngs/Figure2-PubMed.png
# !convert -flatten -density 300 -trim ../figures/Figure2-PubMed.pdf -compress LZW -quality 100 ../figures/Figure2-PubMed.tif
display(Image("../figures/pngs/Figure2-PubMed.png", width=450))

# %% [markdown]
# # Figure 3

# %%
# converting svg to pdf
figure_name = 'Fig_inc_pdf'
# !convert -density 343 ../figures/draft/{figure_name}.svg ../figures/draft/{figure_name}.pdf

# %%
# %%capture
# %%bash
pdflatex <<TeXScript
\documentclass{standalone}
\usepackage{tikz,graphicx}
\usepackage[T1]{fontenc}

\begin{document}
\begin{tikzpicture}
    \node[anchor=south west] at (1.1in, 0in) {\includegraphics[width=3.25in]{../figures/draft/Fig_inc_pdf.pdf}};
    \node[anchor=north west] at (0.7in, -4.2in) {\includegraphics[width=4.5in]{../figures/draft/fig-incper_Reviews.pdf}};
    \node[anchor=north west] at (-0in, 0in) {\includegraphics[width=5.2in]{../figures/draft/fig-incper_Omicron_meta.pdf}};
    \node[anchor=south east] at (.7in,-4.1in) {\large{\bf C}};
    \node[anchor=south east] at (1.1in,2.12in) {\large{\bf A}};
    \node[anchor=south east] at (.2in,-.06in) {\large{\bf B}};
\end{tikzpicture}
\end{document}
TeXScript
mv texput.pdf ../figures/Figure3.pdf
rm texput.*

# %%
figure_name = 'Figure3'
# !convert -flatten -density 300 -trim ../figures/{figure_name}.pdf -quality 100 ../figures/pngs/{figure_name}.png
# !convert -density 300 ../figures/{figure_name}.pdf -compress LZW -quality 100 -background White -layers flatten ../figures/{figure_name}.tif
display(Image(f"../figures/pngs/{figure_name}.png", width=600))

# %% [markdown]
# # Supplementary Figure 1

# %%
# converting svg to pdf
for figure_name in ['Fig_inc_per_ecdf_cdf', 'Fig_inc_per_ecdf_vaccinated_and_nonvaccinated', 'Fig_inc_per_age_group']:
    # !convert -density 343 ../figures/draft/{figure_name}.svg ../figures/draft/{figure_name}.pdf

# %%
# %%capture
# %%bash
pdflatex <<TeXScript
\documentclass{standalone}
\usepackage{tikz,graphicx}
\usepackage[T1]{fontenc}

\begin{document}
\begin{tikzpicture}
    \node[anchor=south east] at (0in, 0in) {\includegraphics[width=3.5in]{../figures/draft/Fig_inc_per_ecdf_cdf.pdf}};
    \node[anchor=north east] at (0in, 0in) {\includegraphics[width=3.5in]{../figures/draft/Fig_inc_per_ecdf_vaccinated_and_nonvaccinated.pdf}};
    \node[anchor=north west] at (0in, 0in) {\includegraphics[width=3.5in]{../figures/draft/Fig_inc_per_age_group.pdf}};
    \node[anchor=south east] at (-3.45in,2.45in) {\large{\bf A}};
    \node[anchor=south east] at (.15in,-.1in) {\large{\bf C}};
    \node[anchor=south east] at (-3.45in,-.1in) {\large{\bf B}};
\end{tikzpicture}
\end{document}
TeXScript
mv texput.pdf ../figures/FigureS1.pdf
rm texput.*

# %%
figure_name = 'FigureS1'
# !convert -flatten -density 300 -trim ../figures/{figure_name}.pdf -quality 100 ../figures/pngs/{figure_name}.png
# !convert -density 300 ../figures/{figure_name}.pdf -compress LZW -quality 100 -background White -layers flatten ../figures/{figure_name}.tif
display(Image(f"../figures/pngs/{figure_name}.png", width=600))

# %% [markdown]
# # Supplementary Figure 2

# %%
# converting svg to pdf
for figure_name in ['Fig_inc_per_ecdf_cdf', 'Fig_inc_per_ecdf_vaccinated_and_nonvaccinated', 'Fig_inc_per_age_group']:
    # !convert -density 343 ../figures/draft/{figure_name}.svg ../figures/draft/{figure_name}.pdf

# %%
# %%capture
# %%bash
pdflatex <<TeXScript
\documentclass{standalone}
\usepackage{tikz,graphicx}
\usepackage[T1]{fontenc}

\begin{document}
\begin{tikzpicture}
    \node[anchor=south east] at (0in, 0in) {\includegraphics[width=3.5in]{../figures/draft/Fig_inc_per_ecdf_cdf.pdf}};
    \node[anchor=north east] at (0in, 0in) {\includegraphics[width=3.5in]{../figures/draft/Fig_inc_per_ecdf_vaccinated_and_nonvaccinated.pdf}};
    \node[anchor=north west] at (0in, 0in) {\includegraphics[width=3.5in]{../figures/draft/Fig_inc_per_age_group.pdf}};
    \node[anchor=south east] at (-3.45in,2.45in) {\large{\bf A}};
    \node[anchor=south east] at (.15in,-.1in) {\large{\bf C}};
    \node[anchor=south east] at (-3.45in,-.1in) {\large{\bf B}};
\end{tikzpicture}
\end{document}
TeXScript
mv texput.pdf ../figures/FigureS1.pdf
rm texput.*

# %%
figure_name = 'FigureS1'
# !convert -flatten -density 300 -trim ../figures/{figure_name}.pdf -quality 100 ../figures/pngs/{figure_name}.png
# !convert -density 300 ../figures/{figure_name}.pdf -compress LZW -quality 100 -background White -layers flatten ../figures/{figure_name}.tif
display(Image(f"../figures/pngs/{figure_name}.png", width=600))
